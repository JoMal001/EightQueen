# %% [markdown]
# <a href="https://colab.research.google.com/github/JoMal001/EightQueen/blob/master/8Queen_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Generate chromosomes for Population <<<<<<<<<<<<<<<<<<<<<<<<<<<
def generate_chromosome(size): 
    return [ random.randint(0, size - 1) for _ in range(size) ]

# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Fitness Function <<<<<<<<<<<<<<<<<<<<<<<<<<<
def fitness(chromosome):
    horizontal_collisions = sum([chromosome.count(queen)-1 for queen in chromosome])/2
    diagonal_collisions = 0

    n = len(chromosome)
    left_diagonal = 0
    right_diagonal = 0
    for i in range(n):
      if i>0:
        for j in range(1, i+1):
          if (chromosome[i-j] == chromosome[i]-j) or (chromosome[i-j] == chromosome[i]+j):
            left_diagonal+=1
    for i in range(n-2, -1, -1):
      if i < n-1:
        for j in range(1,n-i):
          if (chromosome[i+j] == chromosome[i]-j) or (chromosome[i+j] == chromosome[i]+j):
           right_diagonal+=1
    diagonal_collisions = (left_diagonal + right_diagonal)/2

    return int(maxFitness - (horizontal_collisions + diagonal_collisions)) #28-(2+3)=23

# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Calculate Probability <<<<<<<<<<<<<<<<<<<<<<<<<<<
def probability(chromosome, fitness):
    return fitness(chromosome) / maxFitness

# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Randomply pick a chromosome for cross over <<<<<<<<<<<<<<<<<<<<<<<<<<<
def pick_chromosome(population, probabilities):
    populationWithProbabilty = zip(population, probabilities)
    total = sum(p for c, p in populationWithProbabilty)
    r = random.uniform(0, total)
    counter = 0
    for c, p in zip(population, probabilities):
        if counter + p >= r:
            return c
        counter += p
    
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Cross Over Function <<<<<<<<<<<<<<<<<<<<<<<<<<<        
def reproduce(x, y): 
    n = len(x)
    c = random.randint(0, n - 1)
    return x[0:c] + y[c:n]

# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Mutation Function - to change any random value of chromosome <<<<<<<<<<<<<<<<<<<<<<<<<<<
def mutate(x): 
    n = len(x)
    c = random.randint(0, n - 1)
    m = random.randint(0, n - 1)
    x[c] = m
    return x

# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Generate New Population <<<<<<<<<<<<<<<<<<<<<<<<<<<
def genetic_queen(population, fitness):
    mutation_probability = 0.03
    new_population = []
    probabilities = [probability(n, fitness) for n in population]
    for i in range(len(population)):
        x = pick_chromosome(population, probabilities) 
        y = pick_chromosome(population, probabilities) 
        child = reproduce(x, y) 
        if random.random() < mutation_probability:
            child = mutate(child)
        print_chromosome(child)
        new_population.append(child)
        if fitness(child) == maxFitness: break
    return new_population

def print_chromosome(chrom):
    print("Chromosome = {},  Fitness = {}"
        .format(str(chrom), fitness(chrom)))

if __name__ == "__main__":
    nq = 8
    maxFitness = (nq*(nq-1))/2  # 8*7/2 = 28
    population = [generate_chromosome(nq) for _ in range(100)]
    
    generation = 1

    while not maxFitness in [fitness(chrom) for chrom in population]:
        print(">>> Generation {} <<".format(generation))
        population = genetic_queen(population, fitness)
        print("")
        print("Maximum Fitness = {}".format(max([fitness(n) for n in population])))
        generation += 1
    
    print("Solved in Generation {}".format(generation-1))
    for chrom in population:
        if fitness(chrom) == maxFitness:
            print("");
            print("One of the possible solutions: ")
            print_chromosome(chrom)
# Out:
# Streaming output truncated to the last 5000 lines.
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [2, 0, 6, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
#
# Maximum Fitness = 27
# >>> Generation 491 <<
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 6, 7, 5, 1, 2, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [2, 0, 6, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [2, 0, 6, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [6, 2, 7, 5, 1, 1, 6, 5],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 4, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 4, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 5, 0],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
#
# Maximum Fitness = 27
# >>> Generation 492 <<
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [2, 0, 6, 5, 1, 2, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 5, 0],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [6, 2, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 5],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [2, 0, 6, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 0, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [6, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 6, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 0, 5, 1, 0, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [6, 2, 7, 5, 1, 1, 6, 5],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 5],  Fitness = 25
# Chromosome = [4, 6, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
#
# Maximum Fitness = 27
# >>> Generation 493 <<
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 7, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 6, 5, 1, 2, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 5],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 6, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [6, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [6, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 5],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [6, 2, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [6, 2, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 5],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 5],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 5],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 0, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [6, 2, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 4, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
#
# Maximum Fitness = 27
# >>> Generation 494 <<
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [2, 2, 7, 5, 1, 6, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 0],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 5],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 5],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 4, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 6, 5, 1, 2, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [6, 2, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 5],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
#
# Maximum Fitness = 27
# >>> Generation 495 <<
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 5],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [2, 2, 7, 5, 1, 2, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 4, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 0],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 4, 1, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [2, 2, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 4, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [6, 2, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [1, 0, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 6, 5, 1, 2, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
#
# Maximum Fitness = 27
# >>> Generation 496 <<
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 4, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 6, 5, 1, 2, 6, 3],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 4, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 4, 1, 6, 0],  Fitness = 24
# Chromosome = [4, 2, 7, 0, 1, 2, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 2, 5, 1, 7, 6, 3],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [1, 0, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 0],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 4, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
#
# Maximum Fitness = 27
# >>> Generation 497 <<
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 0, 1, 2, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 2, 5, 1, 7, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 0],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 0, 1, 2, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 0],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 4, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 7, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 2, 5, 1, 1, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 4, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 2, 7, 0, 1, 2, 6, 3],  Fitness = 23
# Chromosome = [1, 0, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
#
# Maximum Fitness = 27
# >>> Generation 498 <<
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 1],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [1, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [0, 0, 7, 5, 1, 0, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 2, 5, 1, 7, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 2, 5, 1, 7, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 0],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
#
# Maximum Fitness = 27
# >>> Generation 499 <<
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 1],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 1, 1],  Fitness = 21
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 0],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 2, 5, 1, 7, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 7],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 1],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 5, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 0],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 0],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [1, 0, 2, 5, 1, 7, 6, 3],  Fitness = 23
# ...
# Chromosome = [4, 2, 7, 5, 6, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 6, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 6, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 0, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 5],  Fitness = 23
# Chromosome = [4, 1, 7, 5, 1, 2, 6, 4],  Fitness = 22
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 4, 5, 1, 0, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 6, 5, 2, 2, 6, 4],  Fitness = 21
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 2, 1, 3],  Fitness = 23
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 4],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 2],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 4],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 4],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 5],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 2, 0, 6, 3],  Fitness = 27
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 4],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 5],  Fitness = 25
# Chromosome = [0, 2, 2, 5, 3, 1, 6, 3],  Fitness = 22
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
#
# Maximum Fitness = 27
# >>> Generation 537 <<
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 2, 0, 6, 3],  Fitness = 27
# Chromosome = [0, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 1, 7, 5, 1, 2, 6, 4],  Fitness = 22
# Chromosome = [4, 3, 6, 5, 1, 2, 6, 3],  Fitness = 21
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 7, 1, 2, 6, 3],  Fitness = 24
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 2, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 1, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 1, 3],  Fitness = 25
# Chromosome = [4, 3, 6, 5, 1, 6, 6, 3],  Fitness = 20
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 2],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 1, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 5],  Fitness = 24
# Chromosome = [0, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 1, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [0, 0, 7, 5, 2, 1, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 3, 6, 5, 1, 0, 6, 3],  Fitness = 21
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 4, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 0, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 5],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 6, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [2, 0, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 0, 6, 3],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 4, 5, 1, 2, 6, 5],  Fitness = 23
# Chromosome = [2, 0, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 3, 6, 5, 1, 6, 6, 3],  Fitness = 20
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 4],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 5],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [0, 1, 7, 5, 2, 0, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 6, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 5],  Fitness = 25
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [2, 0, 7, 5, 1, 1, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 2, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 2, 5, 3, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 3, 6, 5, 1, 6, 6, 3],  Fitness = 20
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
#
# Maximum Fitness = 27
# >>> Generation 538 <<
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 2, 5, 3, 1, 6, 3],  Fitness = 23
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [0, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 5],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 4],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 5],  Fitness = 24
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 6, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [0, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 3, 6, 5, 6, 1, 6, 3],  Fitness = 16
# Chromosome = [2, 0, 7, 5, 1, 2, 1, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 5],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 4],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 4],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 6, 1, 6, 3],  Fitness = 22
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 2, 6, 6, 3],  Fitness = 26
# Chromosome = [2, 0, 7, 5, 1, 1, 6, 3],  Fitness = 25
# Chromosome = [4, 3, 6, 5, 1, 1, 6, 3],  Fitness = 20
# Chromosome = [2, 0, 7, 5, 1, 1, 6, 3],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 0, 6, 3],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 1, 7, 5, 2, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 6, 7, 5, 1, 6, 6, 3],  Fitness = 24
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 4],  Fitness = 23
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 3, 7, 5, 1, 6, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 2, 6, 6, 5],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 6, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 6, 1, 6, 3],  Fitness = 22
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 5],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [0, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 1, 6, 3],  Fitness = 25
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [0, 1, 7, 5, 2, 0, 6, 3],  Fitness = 24
# Chromosome = [2, 0, 3, 5, 1, 2, 6, 3],  Fitness = 23
# Chromosome = [2, 0, 7, 5, 1, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 2, 1, 3],  Fitness = 23
# Chromosome = [2, 1, 7, 5, 1, 0, 6, 3],  Fitness = 23
# Chromosome = [4, 2, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 4, 5, 1, 2, 6, 5],  Fitness = 21
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 3],  Fitness = 27
# Chromosome = [0, 0, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 0, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 2, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [2, 0, 7, 7, 1, 2, 6, 3],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 4],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [0, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 0, 6, 3],  Fitness = 27
#
# Maximum Fitness = 27
# >>> Generation 539 <<
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 6, 6, 1],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 0, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 6, 1, 1, 3],  Fitness = 22
# Chromosome = [0, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 1, 7, 5, 2, 6, 6, 3],  Fitness = 26
# Chromosome = [4, 1, 7, 5, 1, 0, 6, 3],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 2, 1, 3],  Fitness = 23
# Chromosome = [4, 2, 2, 5, 3, 1, 6, 3],  Fitness = 23
# Chromosome = [4, 1, 7, 5, 2, 2, 6, 4],  Fitness = 24
# Chromosome = [4, 2, 7, 5, 1, 2, 6, 4],  Fitness = 23
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [4, 0, 7, 5, 1, 1, 6, 3],  Fitness = 26
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 1, 7, 5, 1, 6, 6, 3],  Fitness = 25
# Chromosome = [2, 0, 7, 5, 1, 2, 6, 3],  Fitness = 25
# Chromosome = [4, 2, 7, 5, 0, 6, 6, 3],  Fitness = 24
# Chromosome = [0, 0, 7, 5, 1, 1, 6, 3],  Fitness = 24
# Chromosome = [4, 0, 7, 5, 1, 2, 6, 3],  Fitness = 27
# Chromosome = [4, 0, 7, 5, 2, 6, 1, 3],  Fitness = 28
#
# Maximum Fitness = 28
# Solved in Generation 539
#
# One of the possible solutions:
# Chromosome = [4, 0, 7, 5, 2, 6, 1, 3],  Fitness = 28
